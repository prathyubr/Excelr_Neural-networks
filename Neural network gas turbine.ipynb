# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import Adam
from keras.layers import Dropout

# %%
df=pd.read_csv("gas_turbines.csv")
df=df.iloc[:,[7,0,1,2]]
df.shape
# Out:
# (15039, 4)

# %%
df.describe()
# Out:
#                 TEY            AT           AP            AH
# count  15039.000000  15039.000000  15039.00000  15039.000000
# mean     134.188464     17.764381   1013.19924     79.124174
# std       15.829717      7.574323      6.41076     13.793439
# min      100.170000      0.522300    985.85000     30.344000
# 25%      127.985000     11.408000   1008.90000     69.750000
# 50%      133.780000     18.186000   1012.80000     82.266000
# 75%      140.895000     23.862500   1016.90000     90.043500
# max      174.610000     34.929000   1034.20000    100.200000

# %%
df.isnull().sum()
# Out:
# TEY    0
# AT     0
# AP     0
# AH     0
# dtype: int64

# %%
x=df.iloc[:,1:5]
y=df.iloc[:,0]

# %%
x
# Out:
#            AT      AP      AH
# 0      6.8594  1007.9  96.799
# 1      6.7850  1008.4  97.118
# 2      6.8977  1008.8  95.939
# 3      7.0569  1009.2  95.249
# 4      7.3978  1009.7  95.150
# ...       ...     ...     ...
# 15034  9.0301  1005.6  98.460
# 15035  7.8879  1005.9  99.093
# 15036  7.2647  1006.3  99.496
# 15037  7.0060  1006.8  99.008
# 15038  6.9279  1007.2  97.533
#
# [15039 rows x 3 columns]

# %%
y
# Out:
# 0        114.70
# 1        114.72
# 2        114.71
# 3        114.72
# 4        114.72
#           ...
# 15034    111.61
# 15035    111.78
# 15036    110.19
# 15037    110.74
# 15038    111.58
# Name: TEY, Length: 15039, dtype: float64

# %%
seed = 7
np.random.seed(seed)
model = Sequential()
model.add(Dense(12, input_dim=3,  kernel_initializer='uniform', activation='relu'))
model.add(Dense(8,  kernel_initializer='uniform', activation='relu'))
model.add(Dense(1,  kernel_initializer='uniform', activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history= model.fit(x, y,validation_split=0.33, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 1008/1008 [==============================] - 4s 4ms/step - loss: -4588953.5000 - accuracy: 0.0000e+00 - val_loss: -17759206.0000 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 1008/1008 [==============================] - 4s 4ms/step - loss: -61376456.0000 - accuracy: 0.0000e+00 - val_loss: -120416464.0000 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -227137264.0000 - accuracy: 0.0000e+00 - val_loss: -345292928.0000 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -528358560.0000 - accuracy: 0.0000e+00 - val_loss: -710989696.0000 - val_accuracy: 0.0000e+00
# Epoch 5/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -981247552.0000 - accuracy: 0.0000e+00 - val_loss: -1232011136.0000 - val_accuracy: 0.0000e+00
# Epoch 6/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1601371776.0000 - accuracy: 0.0000e+00 - val_loss: -1923767424.0000 - val_accuracy: 0.0000e+00
# Epoch 7/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -2404489472.0000 - accuracy: 0.0000e+00 - val_loss: -2801940736.0000 - val_accuracy: 0.0000e+00
# Epoch 8/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -3406171648.0000 - accuracy: 0.0000e+00 - val_loss: -3881710080.0000 - val_accuracy: 0.0000e+00
# Epoch 9/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -4623524864.0000 - accuracy: 0.0000e+00 - val_loss: -5180088320.0000 - val_accuracy: 0.0000e+00
# Epoch 10/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -6072608768.0000 - accuracy: 0.0000e+00 - val_loss: -6712536064.0000 - val_accuracy: 0.0000e+00
# Epoch 11/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -7769764864.0000 - accuracy: 0.0000e+00 - val_loss: -8495099904.0000 - val_accuracy: 0.0000e+00
# Epoch 12/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -9731767296.0000 - accuracy: 0.0000e+00 - val_loss: -10544522240.0000 - val_accuracy: 0.0000e+00
# Epoch 13/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -11974156288.0000 - accuracy: 0.0000e+00 - val_loss: -12874130432.0000 - val_accuracy: 0.0000e+00
# Epoch 14/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -14512592896.0000 - accuracy: 0.0000e+00 - val_loss: -15501053952.0000 - val_accuracy: 0.0000e+00
# Epoch 15/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -17363378176.0000 - accuracy: 0.0000e+00 - val_loss: -18441570304.0000 - val_accuracy: 0.0000e+00
# Epoch 16/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -20545230848.0000 - accuracy: 0.0000e+00 - val_loss: -21712551936.0000 - val_accuracy: 0.0000e+00
# Epoch 17/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -24072349696.0000 - accuracy: 0.0000e+00 - val_loss: -25327245312.0000 - val_accuracy: 0.0000e+00
# Epoch 18/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -27960102912.0000 - accuracy: 0.0000e+00 - val_loss: -29301905408.0000 - val_accuracy: 0.0000e+00
# Epoch 19/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -32224202752.0000 - accuracy: 0.0000e+00 - val_loss: -33651656704.0000 - val_accuracy: 0.0000e+00
# Epoch 20/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -36881428480.0000 - accuracy: 0.0000e+00 - val_loss: -38392811520.0000 - val_accuracy: 0.0000e+00
# Epoch 21/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -41947639808.0000 - accuracy: 0.0000e+00 - val_loss: -43541819392.0000 - val_accuracy: 0.0000e+00
# Epoch 22/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -47438356480.0000 - accuracy: 0.0000e+00 - val_loss: -49110257664.0000 - val_accuracy: 0.0000e+00
# Epoch 23/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -53368832000.0000 - accuracy: 0.0000e+00 - val_loss: -55118073856.0000 - val_accuracy: 0.0000e+00
# Epoch 24/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -59753717760.0000 - accuracy: 0.0000e+00 - val_loss: -61573943296.0000 - val_accuracy: 0.0000e+00
# Epoch 25/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -66609528832.0000 - accuracy: 0.0000e+00 - val_loss: -68500275200.0000 - val_accuracy: 0.0000e+00
# Epoch 26/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -73951748096.0000 - accuracy: 0.0000e+00 - val_loss: -75906531328.0000 - val_accuracy: 0.0000e+00
# Epoch 27/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -81795063808.0000 - accuracy: 0.0000e+00 - val_loss: -83809599488.0000 - val_accuracy: 0.0000e+00
# Epoch 28/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -90155884544.0000 - accuracy: 0.0000e+00 - val_loss: -92225978368.0000 - val_accuracy: 0.0000e+00
# Epoch 29/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -99053699072.0000 - accuracy: 0.0000e+00 - val_loss: -101173796864.0000 - val_accuracy: 0.0000e+00
# Epoch 30/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -108499279872.0000 - accuracy: 0.0000e+00 - val_loss: -110662418432.0000 - val_accuracy: 0.0000e+00
# Epoch 31/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -118505291776.0000 - accuracy: 0.0000e+00 - val_loss: -120704671744.0000 - val_accuracy: 0.0000e+00
# Epoch 32/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -129090543616.0000 - accuracy: 0.0000e+00 - val_loss: -131324600320.0000 - val_accuracy: 0.0000e+00
# Epoch 33/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -140275515392.0000 - accuracy: 0.0000e+00 - val_loss: -142534230016.0000 - val_accuracy: 0.0000e+00
# Epoch 34/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -152071077888.0000 - accuracy: 0.0000e+00 - val_loss: -154341900288.0000 - val_accuracy: 0.0000e+00
# Epoch 35/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -164483530752.0000 - accuracy: 0.0000e+00 - val_loss: -166763315200.0000 - val_accuracy: 0.0000e+00
# Epoch 36/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -177539563520.0000 - accuracy: 0.0000e+00 - val_loss: -179821133824.0000 - val_accuracy: 0.0000e+00
# Epoch 37/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -191254167552.0000 - accuracy: 0.0000e+00 - val_loss: -193531084800.0000 - val_accuracy: 0.0000e+00
# Epoch 38/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -205639221248.0000 - accuracy: 0.0000e+00 - val_loss: -207897296896.0000 - val_accuracy: 0.0000e+00
# Epoch 39/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -220713533440.0000 - accuracy: 0.0000e+00 - val_loss: -222950129664.0000 - val_accuracy: 0.0000e+00
# Epoch 40/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -236490178560.0000 - accuracy: 0.0000e+00 - val_loss: -238688305152.0000 - val_accuracy: 0.0000e+00
# Epoch 41/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -252975775744.0000 - accuracy: 0.0000e+00 - val_loss: -255130320896.0000 - val_accuracy: 0.0000e+00
# Epoch 42/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -270202028032.0000 - accuracy: 0.0000e+00 - val_loss: -272301260800.0000 - val_accuracy: 0.0000e+00
# Epoch 43/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -288173096960.0000 - accuracy: 0.0000e+00 - val_loss: -290208874496.0000 - val_accuracy: 0.0000e+00
# Epoch 44/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -306908004352.0000 - accuracy: 0.0000e+00 - val_loss: -308863565824.0000 - val_accuracy: 0.0000e+00
# Epoch 45/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -326425411584.0000 - accuracy: 0.0000e+00 - val_loss: -328296071168.0000 - val_accuracy: 0.0000e+00
# Epoch 46/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -346734690304.0000 - accuracy: 0.0000e+00 - val_loss: -348496494592.0000 - val_accuracy: 0.0000e+00
# Epoch 47/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -367842721792.0000 - accuracy: 0.0000e+00 - val_loss: -369498587136.0000 - val_accuracy: 0.0000e+00
# Epoch 48/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -389777752064.0000 - accuracy: 0.0000e+00 - val_loss: -391305756672.0000 - val_accuracy: 0.0000e+00
# Epoch 49/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -412550889472.0000 - accuracy: 0.0000e+00 - val_loss: -413942153216.0000 - val_accuracy: 0.0000e+00
# Epoch 50/150
# 1008/1008 [==============================] - 3s 2ms/step - loss: -436179894272.0000 - accuracy: 0.0000e+00 - val_loss: -437416296448.0000 - val_accuracy: 0.0000e+00
# Epoch 51/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -460680429568.0000 - accuracy: 0.0000e+00 - val_loss: -461753614336.0000 - val_accuracy: 0.0000e+00
# Epoch 52/150
# 1008/1008 [==============================] - 3s 2ms/step - loss: -486070222848.0000 - accuracy: 0.0000e+00 - val_loss: -486966788096.0000 - val_accuracy: 0.0000e+00
# Epoch 53/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -512353435648.0000 - accuracy: 0.0000e+00 - val_loss: -513052311552.0000 - val_accuracy: 0.0000e+00
# Epoch 54/150
# 1008/1008 [==============================] - 3s 2ms/step - loss: -539548942336.0000 - accuracy: 0.0000e+00 - val_loss: -540038922240.0000 - val_accuracy: 0.0000e+00
# Epoch 55/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -567666212864.0000 - accuracy: 0.0000e+00 - val_loss: -567932747776.0000 - val_accuracy: 0.0000e+00
# Epoch 56/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -596738965504.0000 - accuracy: 0.0000e+00 - val_loss: -596769636352.0000 - val_accuracy: 0.0000e+00
# Epoch 57/150
# 1008/1008 [==============================] - 3s 2ms/step - loss: -626767822848.0000 - accuracy: 0.0000e+00 - val_loss: -626535301120.0000 - val_accuracy: 0.0000e+00
# Epoch 58/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -657774411776.0000 - accuracy: 0.0000e+00 - val_loss: -657286234112.0000 - val_accuracy: 0.0000e+00
# Epoch 59/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -689777803264.0000 - accuracy: 0.0000e+00 - val_loss: -688985079808.0000 - val_accuracy: 0.0000e+00
# Epoch 60/150
# 1008/1008 [==============================] - 3s 2ms/step - loss: -722771378176.0000 - accuracy: 0.0000e+00 - val_loss: -721677910016.0000 - val_accuracy: 0.0000e+00
# Epoch 61/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -756790460416.0000 - accuracy: 0.0000e+00 - val_loss: -755369050112.0000 - val_accuracy: 0.0000e+00
# Epoch 62/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -791846912000.0000 - accuracy: 0.0000e+00 - val_loss: -790097035264.0000 - val_accuracy: 0.0000e+00
# Epoch 63/150
# 1008/1008 [==============================] - 3s 2ms/step - loss: -827952857088.0000 - accuracy: 0.0000e+00 - val_loss: -825840304128.0000 - val_accuracy: 0.0000e+00
# Epoch 64/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -865105805312.0000 - accuracy: 0.0000e+00 - val_loss: -862612094976.0000 - val_accuracy: 0.0000e+00
# Epoch 65/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -903352877056.0000 - accuracy: 0.0000e+00 - val_loss: -900473094144.0000 - val_accuracy: 0.0000e+00
# Epoch 66/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -942709735424.0000 - accuracy: 0.0000e+00 - val_loss: -939409014784.0000 - val_accuracy: 0.0000e+00
# Epoch 67/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -983156195328.0000 - accuracy: 0.0000e+00 - val_loss: -979417432064.0000 - val_accuracy: 0.0000e+00
# Epoch 68/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1024749928448.0000 - accuracy: 0.0000e+00 - val_loss: -1020566700032.0000 - val_accuracy: 0.0000e+00
# Epoch 69/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1067460067328.0000 - accuracy: 0.0000e+00 - val_loss: -1062783418368.0000 - val_accuracy: 0.0000e+00
# Epoch 70/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1111319773184.0000 - accuracy: 0.0000e+00 - val_loss: -1106151342080.0000 - val_accuracy: 0.0000e+00
# Epoch 71/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -1156355588096.0000 - accuracy: 0.0000e+00 - val_loss: -1150677942272.0000 - val_accuracy: 0.0000e+00
# Epoch 72/150
# 1008/1008 [==============================] - 3s 2ms/step - loss: -1202591891456.0000 - accuracy: 0.0000e+00 - val_loss: -1196380782592.0000 - val_accuracy: 0.0000e+00
# Epoch 73/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1250031042560.0000 - accuracy: 0.0000e+00 - val_loss: -1243263533056.0000 - val_accuracy: 0.0000e+00
# Epoch 74/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1298666618880.0000 - accuracy: 0.0000e+00 - val_loss: -1291302731776.0000 - val_accuracy: 0.0000e+00
# Epoch 75/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1348540825600.0000 - accuracy: 0.0000e+00 - val_loss: -1340586196992.0000 - val_accuracy: 0.0000e+00
# Epoch 76/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1399663755264.0000 - accuracy: 0.0000e+00 - val_loss: -1391062417408.0000 - val_accuracy: 0.0000e+00
# Epoch 77/150
# 1008/1008 [==============================] - 3s 2ms/step - loss: -1452041830400.0000 - accuracy: 0.0000e+00 - val_loss: -1442808332288.0000 - val_accuracy: 0.0000e+00
# Epoch 78/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1505713979392.0000 - accuracy: 0.0000e+00 - val_loss: -1495805067264.0000 - val_accuracy: 0.0000e+00
# Epoch 79/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1560650055680.0000 - accuracy: 0.0000e+00 - val_loss: -1550024704000.0000 - val_accuracy: 0.0000e+00
# Epoch 80/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1616894361600.0000 - accuracy: 0.0000e+00 - val_loss: -1605565677568.0000 - val_accuracy: 0.0000e+00
# Epoch 81/150
# 1008/1008 [==============================] - 3s 2ms/step - loss: -1674454892544.0000 - accuracy: 0.0000e+00 - val_loss: -1662359568384.0000 - val_accuracy: 0.0000e+00
# Epoch 82/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1733359173632.0000 - accuracy: 0.0000e+00 - val_loss: -1720507301888.0000 - val_accuracy: 0.0000e+00
# Epoch 83/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1793615986688.0000 - accuracy: 0.0000e+00 - val_loss: -1779957628928.0000 - val_accuracy: 0.0000e+00
# Epoch 84/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1855220875264.0000 - accuracy: 0.0000e+00 - val_loss: -1840729292800.0000 - val_accuracy: 0.0000e+00
# Epoch 85/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1918207787008.0000 - accuracy: 0.0000e+00 - val_loss: -1902880096256.0000 - val_accuracy: 0.0000e+00
# Epoch 86/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -1982615519232.0000 - accuracy: 0.0000e+00 - val_loss: -1966407942144.0000 - val_accuracy: 0.0000e+00
# Epoch 87/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -2048412352512.0000 - accuracy: 0.0000e+00 - val_loss: -2031301689344.0000 - val_accuracy: 0.0000e+00
# Epoch 88/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -2115629219840.0000 - accuracy: 0.0000e+00 - val_loss: -2097579687936.0000 - val_accuracy: 0.0000e+00
# Epoch 89/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -2184293515264.0000 - accuracy: 0.0000e+00 - val_loss: -2165300396032.0000 - val_accuracy: 0.0000e+00
# Epoch 90/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -2254401437696.0000 - accuracy: 0.0000e+00 - val_loss: -2234411646976.0000 - val_accuracy: 0.0000e+00
# Epoch 91/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -2326007119872.0000 - accuracy: 0.0000e+00 - val_loss: -2305014104064.0000 - val_accuracy: 0.0000e+00
# Epoch 92/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -2399080284160.0000 - accuracy: 0.0000e+00 - val_loss: -2377030828032.0000 - val_accuracy: 0.0000e+00
# Epoch 93/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -2473638494208.0000 - accuracy: 0.0000e+00 - val_loss: -2450522374144.0000 - val_accuracy: 0.0000e+00
# Epoch 94/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -2549727100928.0000 - accuracy: 0.0000e+00 - val_loss: -2525513646080.0000 - val_accuracy: 0.0000e+00
# Epoch 95/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -2627356852224.0000 - accuracy: 0.0000e+00 - val_loss: -2602010411008.0000 - val_accuracy: 0.0000e+00
# Epoch 96/150
# 1008/1008 [==============================] - 3s 2ms/step - loss: -2706523291648.0000 - accuracy: 0.0000e+00 - val_loss: -2680018173952.0000 - val_accuracy: 0.0000e+00
# Epoch 97/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -2787259973632.0000 - accuracy: 0.0000e+00 - val_loss: -2759548731392.0000 - val_accuracy: 0.0000e+00
# Epoch 98/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -2869535703040.0000 - accuracy: 0.0000e+00 - val_loss: -2840596316160.0000 - val_accuracy: 0.0000e+00
# Epoch 99/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -2953410772992.0000 - accuracy: 0.0000e+00 - val_loss: -2923220697088.0000 - val_accuracy: 0.0000e+00
# Epoch 100/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3038891737088.0000 - accuracy: 0.0000e+00 - val_loss: -3007406407680.0000 - val_accuracy: 0.0000e+00
# Epoch 101/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3125978857472.0000 - accuracy: 0.0000e+00 - val_loss: -3093184118784.0000 - val_accuracy: 0.0000e+00
# Epoch 102/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3214709358592.0000 - accuracy: 0.0000e+00 - val_loss: -3180576374784.0000 - val_accuracy: 0.0000e+00
# Epoch 103/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3305093201920.0000 - accuracy: 0.0000e+00 - val_loss: -3269580816384.0000 - val_accuracy: 0.0000e+00
# Epoch 104/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -3397130387456.0000 - accuracy: 0.0000e+00 - val_loss: -3360185122816.0000 - val_accuracy: 0.0000e+00
# Epoch 105/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -3490857615360.0000 - accuracy: 0.0000e+00 - val_loss: -3452475801600.0000 - val_accuracy: 0.0000e+00
# Epoch 106/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -3586280128512.0000 - accuracy: 0.0000e+00 - val_loss: -3546401472512.0000 - val_accuracy: 0.0000e+00
# Epoch 107/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -3683413131264.0000 - accuracy: 0.0000e+00 - val_loss: -3641999884288.0000 - val_accuracy: 0.0000e+00
# Epoch 108/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -3782228574208.0000 - accuracy: 0.0000e+00 - val_loss: -3739275755520.0000 - val_accuracy: 0.0000e+00
# Epoch 109/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -3882806149120.0000 - accuracy: 0.0000e+00 - val_loss: -3838285709312.0000 - val_accuracy: 0.0000e+00
# Epoch 110/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -3985174167552.0000 - accuracy: 0.0000e+00 - val_loss: -3939028172800.0000 - val_accuracy: 0.0000e+00
# Epoch 111/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -4089322930176.0000 - accuracy: 0.0000e+00 - val_loss: -4041504980992.0000 - val_accuracy: 0.0000e+00
# Epoch 112/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -4195180871680.0000 - accuracy: 0.0000e+00 - val_loss: -4145637752832.0000 - val_accuracy: 0.0000e+00
# Epoch 113/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -4302837383168.0000 - accuracy: 0.0000e+00 - val_loss: -4251587444736.0000 - val_accuracy: 0.0000e+00
# Epoch 114/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -4412331786240.0000 - accuracy: 0.0000e+00 - val_loss: -4359319453696.0000 - val_accuracy: 0.0000e+00
# Epoch 115/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -4523643371520.0000 - accuracy: 0.0000e+00 - val_loss: -4468802322432.0000 - val_accuracy: 0.0000e+00
# Epoch 116/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -4636751167488.0000 - accuracy: 0.0000e+00 - val_loss: -4580079828992.0000 - val_accuracy: 0.0000e+00
# Epoch 117/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -4751760556032.0000 - accuracy: 0.0000e+00 - val_loss: -4693238480896.0000 - val_accuracy: 0.0000e+00
# Epoch 118/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -4868650565632.0000 - accuracy: 0.0000e+00 - val_loss: -4808191770624.0000 - val_accuracy: 0.0000e+00
# Epoch 119/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -4987431157760.0000 - accuracy: 0.0000e+00 - val_loss: -4925025681408.0000 - val_accuracy: 0.0000e+00
# Epoch 120/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -5108120682496.0000 - accuracy: 0.0000e+00 - val_loss: -5043703513088.0000 - val_accuracy: 0.0000e+00
# Epoch 121/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -5230697119744.0000 - accuracy: 0.0000e+00 - val_loss: -5164245712896.0000 - val_accuracy: 0.0000e+00
# Epoch 122/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -5355210276864.0000 - accuracy: 0.0000e+00 - val_loss: -5286699991040.0000 - val_accuracy: 0.0000e+00
# Epoch 123/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -5481717825536.0000 - accuracy: 0.0000e+00 - val_loss: -5411124543488.0000 - val_accuracy: 0.0000e+00
# Epoch 124/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -5610166288384.0000 - accuracy: 0.0000e+00 - val_loss: -5537356316672.0000 - val_accuracy: 0.0000e+00
# Epoch 125/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -5740548849664.0000 - accuracy: 0.0000e+00 - val_loss: -5665558888448.0000 - val_accuracy: 0.0000e+00
# Epoch 126/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -5872921608192.0000 - accuracy: 0.0000e+00 - val_loss: -5795673014272.0000 - val_accuracy: 0.0000e+00
# Epoch 127/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -6007309205504.0000 - accuracy: 0.0000e+00 - val_loss: -5927823998976.0000 - val_accuracy: 0.0000e+00
# Epoch 128/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -6143753584640.0000 - accuracy: 0.0000e+00 - val_loss: -6061942636544.0000 - val_accuracy: 0.0000e+00
# Epoch 129/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -6282159849472.0000 - accuracy: 0.0000e+00 - val_loss: -6197942419456.0000 - val_accuracy: 0.0000e+00
# Epoch 130/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -6422594060288.0000 - accuracy: 0.0000e+00 - val_loss: -6335988498432.0000 - val_accuracy: 0.0000e+00
# Epoch 131/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -6565141676032.0000 - accuracy: 0.0000e+00 - val_loss: -6476149030912.0000 - val_accuracy: 0.0000e+00
# Epoch 132/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -6709778579456.0000 - accuracy: 0.0000e+00 - val_loss: -6618237370368.0000 - val_accuracy: 0.0000e+00
# Epoch 133/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -6856530984960.0000 - accuracy: 0.0000e+00 - val_loss: -6762486824960.0000 - val_accuracy: 0.0000e+00
# Epoch 134/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -7005371105280.0000 - accuracy: 0.0000e+00 - val_loss: -6908765274112.0000 - val_accuracy: 0.0000e+00
# Epoch 135/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -7156365000704.0000 - accuracy: 0.0000e+00 - val_loss: -7057138253824.0000 - val_accuracy: 0.0000e+00
# Epoch 136/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -7309492748288.0000 - accuracy: 0.0000e+00 - val_loss: -7207593181184.0000 - val_accuracy: 0.0000e+00
# Epoch 137/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -7464733900800.0000 - accuracy: 0.0000e+00 - val_loss: -7360097550336.0000 - val_accuracy: 0.0000e+00
# Epoch 138/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -7622122536960.0000 - accuracy: 0.0000e+00 - val_loss: -7514709557248.0000 - val_accuracy: 0.0000e+00
# Epoch 139/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -7781713707008.0000 - accuracy: 0.0000e+00 - val_loss: -7671501553664.0000 - val_accuracy: 0.0000e+00
# Epoch 140/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -7943465992192.0000 - accuracy: 0.0000e+00 - val_loss: -7830412722176.0000 - val_accuracy: 0.0000e+00
# Epoch 141/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -8107445452800.0000 - accuracy: 0.0000e+00 - val_loss: -7991513841664.0000 - val_accuracy: 0.0000e+00
# Epoch 142/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -8273678303232.0000 - accuracy: 0.0000e+00 - val_loss: -8154796523520.0000 - val_accuracy: 0.0000e+00
# Epoch 143/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -8442173456384.0000 - accuracy: 0.0000e+00 - val_loss: -8320354615296.0000 - val_accuracy: 0.0000e+00
# Epoch 144/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -8612974428160.0000 - accuracy: 0.0000e+00 - val_loss: -8488073822208.0000 - val_accuracy: 0.0000e+00
# Epoch 145/150
# 1008/1008 [==============================] - 4s 4ms/step - loss: -8785969545216.0000 - accuracy: 0.0000e+00 - val_loss: -8657983504384.0000 - val_accuracy: 0.0000e+00
# Epoch 146/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -8961237450752.0000 - accuracy: 0.0000e+00 - val_loss: -8830135042048.0000 - val_accuracy: 0.0000e+00
# Epoch 147/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -9138885099520.0000 - accuracy: 0.0000e+00 - val_loss: -9004557271040.0000 - val_accuracy: 0.0000e+00
# Epoch 148/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -9318737903616.0000 - accuracy: 0.0000e+00 - val_loss: -9181160538112.0000 - val_accuracy: 0.0000e+00
# Epoch 149/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -9500935323648.0000 - accuracy: 0.0000e+00 - val_loss: -9360135684096.0000 - val_accuracy: 0.0000e+00
# Epoch 150/150
# 1008/1008 [==============================] - 3s 3ms/step - loss: -9685523496960.0000 - accuracy: 0.0000e+00 - val_loss: -9541338005504.0000 - val_accuracy: 0.0000e+00

# %%
scores = model.evaluate(x, y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 470/470 [==============================] - 1s 2ms/step - loss: -9700358750208.0000 - accuracy: 0.0000e+00
# accuracy: 0.00%

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
a = StandardScaler()
a.fit(x)
X_standardized = a.transform(x)
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1             2
# count  1.503900e+04  1.503900e+04  1.503900e+04
# mean  -2.320107e-16 -1.925280e-14  1.844983e-16
# std    1.000033e+00  1.000033e+00  1.000033e+00
# min   -2.276462e+00 -4.266288e+00 -3.536594e+00
# 25%   -8.392292e-01 -6.706510e-01 -6.796337e-01
# 50%    5.566605e-02 -6.227861e-02  2.277844e-01
# 75%    8.051309e-01  5.772924e-01  7.916582e-01
# max    2.266234e+00  3.275970e+00  1.528011e+00

# %%
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=3, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))\
    
    adam=Adam(lr=0.01)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0)
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# <ipython-input-15-05fa7a3e25fe>:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   model = KerasClassifier(build_fn = create_model,verbose = 0)
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# [CV 1/5; 1/9] END ..................batch_size=10, epochs=10; total time=  20.4s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 1/9] END ..................batch_size=10, epochs=10; total time=  19.4s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 1/9] END ..................batch_size=10, epochs=10; total time=  18.6s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 1/9] END ..................batch_size=10, epochs=10; total time=  18.7s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 1/9] END ..................batch_size=10, epochs=10; total time=  18.5s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 2/9] END ..................batch_size=10, epochs=50; total time= 1.5min
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 2/9] END ..................batch_size=10, epochs=50; total time= 1.5min
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 2/9] END ..................batch_size=10, epochs=50; total time= 1.5min
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 2/9] END ..................batch_size=10, epochs=50; total time= 1.5min
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 2/9] END ..................batch_size=10, epochs=50; total time= 1.5min
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 3/9] END .................batch_size=10, epochs=100; total time= 2.9min
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 3/9] END .................batch_size=10, epochs=100; total time= 3.0min
# [CV 3/5; 3/9] START batch_size=10, epochs=100...................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 3/9] END .................batch_size=10, epochs=100; total time= 2.9min
# [CV 4/5; 3/9] START batch_size=10, epochs=100...................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 3/9] END .................batch_size=10, epochs=100; total time= 2.9min
# [CV 5/5; 3/9] START batch_size=10, epochs=100...................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 3/9] END .................batch_size=10, epochs=100; total time= 3.2min
# [CV 1/5; 4/9] START batch_size=20, epochs=10....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 4/9] END ..................batch_size=20, epochs=10; total time=   9.6s
# [CV 2/5; 4/9] START batch_size=20, epochs=10....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 4/9] END ..................batch_size=20, epochs=10; total time=   9.7s
# [CV 3/5; 4/9] START batch_size=20, epochs=10....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 4/9] END ..................batch_size=20, epochs=10; total time=   9.9s
# [CV 4/5; 4/9] START batch_size=20, epochs=10....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 4/9] END ..................batch_size=20, epochs=10; total time=   9.5s
# [CV 5/5; 4/9] START batch_size=20, epochs=10....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 4/9] END ..................batch_size=20, epochs=10; total time=  10.7s
# [CV 1/5; 5/9] START batch_size=20, epochs=50....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 5/9] END ..................batch_size=20, epochs=50; total time=  45.5s
# [CV 2/5; 5/9] START batch_size=20, epochs=50....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 5/9] END ..................batch_size=20, epochs=50; total time=  44.9s
# [CV 3/5; 5/9] START batch_size=20, epochs=50....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 5/9] END ..................batch_size=20, epochs=50; total time=  43.9s
# [CV 4/5; 5/9] START batch_size=20, epochs=50....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 5/9] END ..................batch_size=20, epochs=50; total time=  44.6s
# [CV 5/5; 5/9] START batch_size=20, epochs=50....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 5/9] END ..................batch_size=20, epochs=50; total time=  45.3s
# [CV 1/5; 6/9] START batch_size=20, epochs=100...................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 6/9] END .................batch_size=20, epochs=100; total time= 1.5min
# [CV 2/5; 6/9] START batch_size=20, epochs=100...................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 6/9] END .................batch_size=20, epochs=100; total time= 1.5min
# [CV 3/5; 6/9] START batch_size=20, epochs=100...................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 6/9] END .................batch_size=20, epochs=100; total time= 1.4min
# [CV 4/5; 6/9] START batch_size=20, epochs=100...................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 6/9] END .................batch_size=20, epochs=100; total time= 1.5min
# [CV 5/5; 6/9] START batch_size=20, epochs=100...................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 6/9] END .................batch_size=20, epochs=100; total time= 1.5min
# [CV 1/5; 7/9] START batch_size=40, epochs=10....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 7/9] END ..................batch_size=40, epochs=10; total time=   5.4s
# [CV 2/5; 7/9] START batch_size=40, epochs=10....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 7/9] END ..................batch_size=40, epochs=10; total time=   6.5s
# [CV 3/5; 7/9] START batch_size=40, epochs=10....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 7/9] END ..................batch_size=40, epochs=10; total time=   5.7s
# [CV 4/5; 7/9] START batch_size=40, epochs=10....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 7/9] END ..................batch_size=40, epochs=10; total time=   5.3s
# [CV 5/5; 7/9] START batch_size=40, epochs=10....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 7/9] END ..................batch_size=40, epochs=10; total time=   5.3s
# [CV 1/5; 8/9] START batch_size=40, epochs=50....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 8/9] END ..................batch_size=40, epochs=50; total time=  22.8s
# [CV 2/5; 8/9] START batch_size=40, epochs=50....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 8/9] END ..................batch_size=40, epochs=50; total time=  22.6s
# [CV 3/5; 8/9] START batch_size=40, epochs=50....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 8/9] END ..................batch_size=40, epochs=50; total time=  22.9s
# [CV 4/5; 8/9] START batch_size=40, epochs=50....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 8/9] END ..................batch_size=40, epochs=50; total time=  22.4s
# [CV 5/5; 8/9] START batch_size=40, epochs=50....................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 8/9] END ..................batch_size=40, epochs=50; total time=  22.8s
# [CV 1/5; 9/9] START batch_size=40, epochs=100...................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 9/9] END .................batch_size=40, epochs=100; total time=  45.4s
# [CV 2/5; 9/9] START batch_size=40, epochs=100...................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 9/9] END .................batch_size=40, epochs=100; total time=  44.5s
# [CV 3/5; 9/9] START batch_size=40, epochs=100...................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 9/9] END .................batch_size=40, epochs=100; total time=  44.4s
# [CV 4/5; 9/9] START batch_size=40, epochs=100...................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 9/9] END .................batch_size=40, epochs=100; total time=  44.0s
# [CV 5/5; 9/9] START batch_size=40, epochs=100...................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 9/9] END .................batch_size=40, epochs=100; total time=  45.9s

# %%
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.0, using {'batch_size': 10, 'epochs': 10}
# 0.0,0.0 with: {'batch_size': 10, 'epochs': 10}
# 0.0,0.0 with: {'batch_size': 10, 'epochs': 50}
# 0.0,0.0 with: {'batch_size': 10, 'epochs': 100}
# 0.0,0.0 with: {'batch_size': 20, 'epochs': 10}
# 0.0,0.0 with: {'batch_size': 20, 'epochs': 50}
# 0.0,0.0 with: {'batch_size': 20, 'epochs': 100}
# 0.0,0.0 with: {'batch_size': 40, 'epochs': 10}
# 0.0,0.0 with: {'batch_size': 40, 'epochs': 50}
# 0.0,0.0 with: {'batch_size': 40, 'epochs': 100}

# %%
def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 3,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4,input_dim = 3,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]

# Make a dictionary of the grid search parameters

param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# <ipython-input-18-38fb56cb5200>:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# [CV 1/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   5.4s
# [CV 2/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   5.9s
# [CV 3/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   5.4s
# [CV 4/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   5.3s
# [CV 5/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 1/9] END .....dropout_rate=0.0, learning_rate=0.001; total time=   5.8s
# [CV 1/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   5.3s
# [CV 2/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   5.3s
# [CV 3/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   5.8s
# [CV 4/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   5.2s
# [CV 5/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 2/9] END ......dropout_rate=0.0, learning_rate=0.01; total time=   5.4s
# [CV 1/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   6.0s
# [CV 2/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   6.4s
# [CV 3/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   5.5s
# [CV 4/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   5.8s
# [CV 5/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 3/9] END .......dropout_rate=0.0, learning_rate=0.1; total time=   5.9s
# [CV 1/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   6.2s
# [CV 2/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   6.6s
# [CV 3/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   5.8s
# [CV 4/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   6.0s
# [CV 5/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 4/9] END .....dropout_rate=0.1, learning_rate=0.001; total time=   5.6s
# [CV 1/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   6.0s
# [CV 2/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   5.7s
# [CV 3/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   5.6s
# [CV 4/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   6.2s
# [CV 5/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 5/9] END ......dropout_rate=0.1, learning_rate=0.01; total time=   5.8s
# [CV 1/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   5.7s
# [CV 2/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   6.1s
# [CV 3/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   5.7s
# [CV 4/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   5.9s
# [CV 5/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 6/9] END .......dropout_rate=0.1, learning_rate=0.1; total time=   5.7s
# [CV 1/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   5.6s
# [CV 2/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   6.2s
# [CV 3/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   6.0s
# [CV 4/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   5.9s
# [CV 5/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 7/9] END .....dropout_rate=0.2, learning_rate=0.001; total time=   7.1s
# [CV 1/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   5.7s
# [CV 2/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   6.2s
# [CV 3/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   5.7s
# [CV 4/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   5.6s
# [CV 5/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 8/9] END ......dropout_rate=0.2, learning_rate=0.01; total time=   6.1s
# [CV 1/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   5.6s
# [CV 2/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   5.7s
# [CV 3/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   6.1s
# [CV 4/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   5.7s
# [CV 5/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 9/9] END .......dropout_rate=0.2, learning_rate=0.1; total time=   6.3s

# %%
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.0, using {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.0,0.0 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.0,0.0 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.0,0.0 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.0,0.0 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.0,0.0 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.0,0.0 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.0,0.0 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.0,0.0 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.0,0.0 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %%
def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 3,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 3,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

# Make a dictionary of the grid search parameters
param_grids = dict(activation_function = activation_function,init = init)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# <ipython-input-21-71e17feed8ca>:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START activation_function=softmax, init=uniform..................
# [CV 1/5; 1/12] END activation_function=softmax, init=uniform; total time=   6.2s
# [CV 2/5; 1/12] START activation_function=softmax, init=uniform..................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 1/12] END activation_function=softmax, init=uniform; total time=   6.3s
# [CV 3/5; 1/12] START activation_function=softmax, init=uniform..................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 1/12] END activation_function=softmax, init=uniform; total time=   6.1s
# [CV 4/5; 1/12] START activation_function=softmax, init=uniform..................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 1/12] END activation_function=softmax, init=uniform; total time=   5.9s
# [CV 5/5; 1/12] START activation_function=softmax, init=uniform..................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 1/12] END activation_function=softmax, init=uniform; total time=   6.5s
# [CV 1/5; 2/12] START activation_function=softmax, init=normal...................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 2/12] END .activation_function=softmax, init=normal; total time=   6.0s
# [CV 2/5; 2/12] START activation_function=softmax, init=normal...................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 2/12] END .activation_function=softmax, init=normal; total time=   6.2s
# [CV 3/5; 2/12] START activation_function=softmax, init=normal...................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 2/12] END .activation_function=softmax, init=normal; total time=   6.2s
# [CV 4/5; 2/12] START activation_function=softmax, init=normal...................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 2/12] END .activation_function=softmax, init=normal; total time=   5.9s
# [CV 5/5; 2/12] START activation_function=softmax, init=normal...................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 2/12] END .activation_function=softmax, init=normal; total time=   6.5s
# [CV 1/5; 3/12] START activation_function=softmax, init=zero.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 3/12] END ...activation_function=softmax, init=zero; total time=   5.9s
# [CV 2/5; 3/12] START activation_function=softmax, init=zero.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 3/12] END ...activation_function=softmax, init=zero; total time=   6.1s
# [CV 3/5; 3/12] START activation_function=softmax, init=zero.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 3/12] END ...activation_function=softmax, init=zero; total time=   7.2s
# [CV 4/5; 3/12] START activation_function=softmax, init=zero.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 3/12] END ...activation_function=softmax, init=zero; total time=   6.4s
# [CV 5/5; 3/12] START activation_function=softmax, init=zero.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 3/12] END ...activation_function=softmax, init=zero; total time=   6.4s
# [CV 1/5; 4/12] START activation_function=relu, init=uniform.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 4/12] END ...activation_function=relu, init=uniform; total time=   6.0s
# [CV 2/5; 4/12] START activation_function=relu, init=uniform.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 4/12] END ...activation_function=relu, init=uniform; total time=   5.6s
# [CV 3/5; 4/12] START activation_function=relu, init=uniform.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 4/12] END ...activation_function=relu, init=uniform; total time=   6.0s
# [CV 4/5; 4/12] START activation_function=relu, init=uniform.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 4/12] END ...activation_function=relu, init=uniform; total time=   5.7s
# [CV 5/5; 4/12] START activation_function=relu, init=uniform.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 4/12] END ...activation_function=relu, init=uniform; total time=   6.2s
# [CV 1/5; 5/12] START activation_function=relu, init=normal......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 5/12] END ....activation_function=relu, init=normal; total time=   5.7s
# [CV 2/5; 5/12] START activation_function=relu, init=normal......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 5/12] END ....activation_function=relu, init=normal; total time=   5.8s
# [CV 3/5; 5/12] START activation_function=relu, init=normal......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 5/12] END ....activation_function=relu, init=normal; total time=   6.3s
# [CV 4/5; 5/12] START activation_function=relu, init=normal......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 5/12] END ....activation_function=relu, init=normal; total time=   5.6s
# [CV 5/5; 5/12] START activation_function=relu, init=normal......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 5/12] END ....activation_function=relu, init=normal; total time=   5.6s
# [CV 1/5; 6/12] START activation_function=relu, init=zero........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 6/12] END ......activation_function=relu, init=zero; total time=   6.1s
# [CV 2/5; 6/12] START activation_function=relu, init=zero........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 6/12] END ......activation_function=relu, init=zero; total time=   5.9s
# [CV 3/5; 6/12] START activation_function=relu, init=zero........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 6/12] END ......activation_function=relu, init=zero; total time=   6.1s
# [CV 4/5; 6/12] START activation_function=relu, init=zero........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 6/12] END ......activation_function=relu, init=zero; total time=   6.0s
# [CV 5/5; 6/12] START activation_function=relu, init=zero........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 6/12] END ......activation_function=relu, init=zero; total time=   5.8s
# [CV 1/5; 7/12] START activation_function=tanh, init=uniform.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   6.2s
# [CV 2/5; 7/12] START activation_function=tanh, init=uniform.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   5.7s
# [CV 3/5; 7/12] START activation_function=tanh, init=uniform.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   5.7s
# [CV 4/5; 7/12] START activation_function=tanh, init=uniform.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   6.2s
# [CV 5/5; 7/12] START activation_function=tanh, init=uniform.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 7/12] END ...activation_function=tanh, init=uniform; total time=   5.6s
# [CV 1/5; 8/12] START activation_function=tanh, init=normal......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 8/12] END ....activation_function=tanh, init=normal; total time=   6.2s
# [CV 2/5; 8/12] START activation_function=tanh, init=normal......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 8/12] END ....activation_function=tanh, init=normal; total time=   7.0s
# [CV 3/5; 8/12] START activation_function=tanh, init=normal......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 8/12] END ....activation_function=tanh, init=normal; total time=   5.6s
# [CV 4/5; 8/12] START activation_function=tanh, init=normal......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 8/12] END ....activation_function=tanh, init=normal; total time=   6.1s
# [CV 5/5; 8/12] START activation_function=tanh, init=normal......................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 8/12] END ....activation_function=tanh, init=normal; total time=   5.6s
# [CV 1/5; 9/12] START activation_function=tanh, init=zero........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 9/12] END ......activation_function=tanh, init=zero; total time=   5.9s
# [CV 2/5; 9/12] START activation_function=tanh, init=zero........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 9/12] END ......activation_function=tanh, init=zero; total time=   5.8s
# [CV 3/5; 9/12] START activation_function=tanh, init=zero........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 9/12] END ......activation_function=tanh, init=zero; total time=   6.1s
# [CV 4/5; 9/12] START activation_function=tanh, init=zero........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 9/12] END ......activation_function=tanh, init=zero; total time=   6.1s
# [CV 5/5; 9/12] START activation_function=tanh, init=zero........................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 9/12] END ......activation_function=tanh, init=zero; total time=   5.7s
# [CV 1/5; 10/12] START activation_function=linear, init=uniform..................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 10/12] END activation_function=linear, init=uniform; total time=   5.5s
# [CV 2/5; 10/12] START activation_function=linear, init=uniform..................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 10/12] END activation_function=linear, init=uniform; total time=   6.1s
# [CV 3/5; 10/12] START activation_function=linear, init=uniform..................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 10/12] END activation_function=linear, init=uniform; total time=   5.8s
# [CV 4/5; 10/12] START activation_function=linear, init=uniform..................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 10/12] END activation_function=linear, init=uniform; total time=   6.4s
# [CV 5/5; 10/12] START activation_function=linear, init=uniform..................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 10/12] END activation_function=linear, init=uniform; total time=   5.7s
# [CV 1/5; 11/12] START activation_function=linear, init=normal...................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 11/12] END .activation_function=linear, init=normal; total time=   5.5s
# [CV 2/5; 11/12] START activation_function=linear, init=normal...................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 11/12] END .activation_function=linear, init=normal; total time=   6.1s
# [CV 3/5; 11/12] START activation_function=linear, init=normal...................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 11/12] END .activation_function=linear, init=normal; total time=   5.8s
# [CV 4/5; 11/12] START activation_function=linear, init=normal...................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 11/12] END .activation_function=linear, init=normal; total time=   5.7s
# [CV 5/5; 11/12] START activation_function=linear, init=normal...................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 11/12] END .activation_function=linear, init=normal; total time=   6.2s
# [CV 1/5; 12/12] START activation_function=linear, init=zero.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 12/12] END ...activation_function=linear, init=zero; total time=   5.6s
# [CV 2/5; 12/12] START activation_function=linear, init=zero.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 12/12] END ...activation_function=linear, init=zero; total time=   5.7s
# [CV 3/5; 12/12] START activation_function=linear, init=zero.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 12/12] END ...activation_function=linear, init=zero; total time=   7.2s
# [CV 4/5; 12/12] START activation_function=linear, init=zero.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 12/12] END ...activation_function=linear, init=zero; total time=   5.7s
# [CV 5/5; 12/12] START activation_function=linear, init=zero.....................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 12/12] END ...activation_function=linear, init=zero; total time=   6.2s

# %%
def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 3,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# <ipython-input-23-67fe63bd7fd4>:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 1/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   6.2s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   7.6s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   7.4s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   5.6s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 1/9] END ......................neuron1=4, neuron2=2; total time=   5.6s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   6.2s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   5.7s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   5.6s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   6.1s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 2/9] END ......................neuron1=4, neuron2=4; total time=   5.6s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   5.8s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   6.1s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   5.6s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   6.2s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 3/9] END ......................neuron1=4, neuron2=8; total time=   5.7s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   5.7s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   6.1s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   5.6s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   5.8s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 4/9] END ......................neuron1=8, neuron2=2; total time=   5.9s
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   5.7s
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   6.1s
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   5.6s
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   6.6s
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 5/9] END ......................neuron1=8, neuron2=4; total time=   6.1s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   5.8s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   6.0s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   5.9s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   5.7s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 6/9] END ......................neuron1=8, neuron2=8; total time=   6.2s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   5.8s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   5.7s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   6.2s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   7.3s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 7/9] END .....................neuron1=16, neuron2=2; total time=   7.4s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   5.7s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   5.7s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   6.1s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   5.8s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 8/9] END .....................neuron1=16, neuron2=4; total time=   6.1s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 1/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   5.8s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 2/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   5.7s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 3/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   6.3s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 4/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   5.8s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# [CV 5/5; 9/9] END .....................neuron1=16, neuron2=8; total time=   5.8s

# %%
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.0, using {'neuron1': 4, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 4, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 4, 'neuron2': 4}
# 0.0,0.0 with: {'neuron1': 4, 'neuron2': 8}
# 0.0,0.0 with: {'neuron1': 8, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 8, 'neuron2': 4}
# 0.0,0.0 with: {'neuron1': 8, 'neuron2': 8}
# 0.0,0.0 with: {'neuron1': 16, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 16, 'neuron2': 4}
# 0.0,0.0 with: {'neuron1': 16, 'neuron2': 8}

# %%
from sklearn.metrics import classification_report, accuracy_score
def create_model():
    model = Sequential()
    model.add(Dense(16,input_dim = 3,kernel_initializer = 'normal',activation = 'linear'))
    model.add(Dropout(0.1))
    model.add(Dense(8,input_dim = 3,kernel_initializer = 'normal',activation = 'linear'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'linear'))
    
    adam = Adam(lr = 0.01) #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 100)

# Fitting the model

model.fit(X_standardized,y)

# Predicting using trained model

y_predict = model.predict(X_standardized)

# Printing the metrics
print(accuracy_score(y_predict.round(),y.round()))
# Out:
# <ipython-input-26-8ec86164b382>:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 100)
# C:\Users\win\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 0.00013298756566261055
